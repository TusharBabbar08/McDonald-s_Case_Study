# %% [markdown]
# # McDonalds Case Study
#
#
#
#
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading the McDonald Data in the notebook

# %%
df=pd.read_csv("Mcdonald .csv")

# %% [markdown]
# # Basic EDA
#
# * Find the shape of the data,data type of individual columns
# * Check the presence of missing values
# * Descriptive stats of numerical columns
# * Find the distribution of numerical columns and the asssociated skeweness and presence of outliers
# * Distribution of categorical columns

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# #### We can successfully conclude that there are no null values

# %%
df.shape
# Out:
# (260, 24)

# %%
print("The number of rows are: ",df.shape[0],"\nThe number of columns are: ",df.shape[1])
# Out:
# The number of rows are:  260
# The number of columns are:  24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# # Checking the Summary of the Dataframe

# %%
df.describe().T
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %% [markdown]
# # Understanding the Data Better

# %%
df.Category.value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df.Category.nunique()
# Out:
# 9

# %% [markdown]
# ### Inference:
# * First column is Category.
# * We have 9 different types of Food offered at McDonalds.
# * The complete list which has Coffee, Tea, Breakfast items is available above.

# %%
df.Item.value_counts().head(10)
# Out:
# Strawberry Shake (Medium)                               1
# Hot Chocolate (Small)                                   1
# Iced Mocha with Nonfat Milk (Small)                     1
# Iced Mocha with Nonfat Milk (Large)                     1
# Nonfat Caramel Mocha (Small)                            1
# Iced Nonfat Caramel Mocha (Large)                       1
# Premium McWrap Chicken Sweet Chili (Grilled Chicken)    1
# Mocha with Nonfat Milk (Large)                          1
# Mocha (Small)                                           1
# McFlurry with M&M’s Candies (Small)                     1
# Name: Item, dtype: int64

# %%
df.Item.nunique()
# Out:
# 260

# %% [markdown]
# ### Inference:
# * 2nd column is Item.
# * We have 260 different types of Food items available at McDonalds.
# * The rest of the columns has Nutrional details of each of the Food items.

# %% [markdown]
# ### After getting an idea of the dataset given, lets proceed to the Questions

# %% [markdown]
# # Q1. Plot graphically which food categories have the highest and lowest varieties

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df["Category"]);

# %% [markdown]
# ## Inference:
#
# ### The highest sales is of :-
# * Coffee and Tea - 95
#
# ### The lowest sales is of :-
# * Salads - 6
#
# * Desserts - 7

# %% [markdown]
# # Q2. Which all variables have an outlier ?

# %% [markdown]
# ### Ans: The best way to check for outliers is by plotting a boxplot, keeping in mind that boxplot only take numerical type data only.

# %%
#Using Descibe to identify all the numerical columns from the data set

df.describe().T
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=df[['Calories','Calories from Fat','Total Fat','Saturated Fat','Total Fat (% Daily Value)']]);

# %% [markdown]
# ## Inference :-
#
#
# ### The columns which have outlier :-
# * Calories
# * Calories from Fat
# * Total fat
# * Total Fat(% Daily Value)
#
# ### The columns which don't have an outlier :-
# * Saturated Fat

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=df[['Saturated Fat (% Daily Value)' ,'Trans Fat','Cholesterol','Cholesterol (% Daily Value)',]]);

# %% [markdown]
# ## Inference :-
#
#
# ### The columns which have an outlier :-
# * Cholestrol
# * Cholestrol (% Daily Value)
#
# ### The columns which don't have an outlier :-
# * Trans Fat
# * Saturated Fat (% Daily Value)

# %%
sns.boxplot(y=df['Trans Fat']);

# %%
df['Trans Fat'].unique()
# Out:
# array([0. , 1. , 0.5, 1.5, 2.5])

# %% [markdown]
# ### Since Trans Fat Data was Unclear from the boxplot, therefore we made a seperate boxplot for that and we can see that it only has 5 unique values.
#
# ### Hence 'Trans Fat' Column does not have an outlier

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=df[['Sodium (% Daily Value)','Carbohydrates','Carbohydrates (% Daily Value)']]);

# %% [markdown]
# ## Inference :-
#
# ### The columns which have an outlier :-
# * Carbohydrates
# * Sodium (% Daily Value)
# * Carbohydrates (% Daily Value)

# %%
sns.boxplot(y=df['Sodium']);

# %% [markdown]
# ## Inference :-
#
# ### The columns which have an outlier :-
# * Sodium

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=df[['Dietary Fiber','Dietary Fiber (% Daily Value)','Sugars','Protein']]);

# %% [markdown]
# ## Inference :-
#
#
# ### The columns which have an outlier :-
# * Dietary Fiber (% Daily Value)
# * Sugars
# * Protein
#
# ### The columns which don't have an outlier :-
# * Dietary Fiber
#
#
# ### An intresting observation, Dietary Fiber does not have an outlier but the same column's Dietary Fiber (% Daily Value) has an outlier.
# ### It denotes that Dietary Fiber in certain, has food items, which are significantly different in Fiber concentration than the other food items.

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=df[['Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]);

# %% [markdown]
# ## Inference :-
#
#
# ### The columns which have an outlier :-
# * Vitamin A (% Daily Value)
# * Vitamin C (% Daily Value)
# * Calcium (% Daily Value)
# * Iron (% Daily Value)

# %% [markdown]
# # Q3. Which variables have the highest correlation? Plot them and find out the value ?
#
#
#
# ## Ans. For depicting the variables with the Highest correlation, I will be selecting the variable - pair which has correlation value of atleast 50% and higher.
# ## I have selected 50% value, as variables having 50% or Higher correlational value represents a High degree of inter - dependence on each other.

# %%
corr = df.corr()
corr
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr,annot=True);

# %% [markdown]
# # Inference :-
#
#
# ## List of Variables which have Correlation with each other.
#
#
# ### This list is with respect to Calories :-
# * Calories & Iron [ 0.64 ]
# * Calories & Sodium [ 0.71 ]
# * Calories & Cholestrol [ 0.68 ]
# * Calories & Saturated Fat [ 0.85 ]
# * Calories & Total Fat [ 0.9 ]
# * Calories & Carbohydrates [ 0.78 ]
#
#
#
# ### This list is with respect to Total Fat :-
# * Total Fat & Iron [ 0.73 ]
# * Total Fat & Protein [ 0.81 ]
# * Total Fat & Dietary Fiber [ 0.58 ]
# * Total Fat & Sodium [ 0.85 ]
# * Total Fat & Cholestrol [ 0.68 ]
# * Total Fat & Saturated Fat [ 0.85 ]
#
#
# ### This list is with respect to Saturated Fat :-
# * Saturated Fat & Iron [ 0.58 ]
# * Saturated Fat & Protein [ 0.6 ]
# * Saturated Fat & Carbohydrates [ 0.58 ]
# * Saturated Fat & Sodium [ 0.58 ]
# * Saturated Fat & Cholestrol [ 0.63 ]
# * Total Fat & Trans Fat [ 0.62 ]
#
#
# ### This list is with respect to Cholestrol :-
# * Cholestrol & Iron [ 0.65 ]
# * Cholestrol & Protein [ 0.56 ]
# * Cholestrol & Sodium [ 0.62 ]
#
#
# ### This list is with respect to Sodium :-
# * Sodium & Iron [ 0.87 ]
# * Sodium & Protein [ 0.87 ]
# * Sodium & Dietary Fiber [ 0.69 ]
#
#
# ### This list is with respect to Carbohydrates :-
# * Carbohydrates & Calcium [ 0.59 ]
# * Carbohydrates & Sugars [ 0.76 ]
#
#
# ### This list is with respect to Dietary Fiber :-
# * Dietary Fiber & Iron [ 0.74 ]
#
#
# ### This list is with respect to Sugars :-
# * Sugars & Calcium [ 0.6 ]
#
#
# ### This list is with respect to Protein :-
# * Protien & Iron [ 0.79 ]
#
#
#
# ### By understanding the correlation between the Food constituents like Protien, Iron,
# ### Calcium, Vitamin A etc, of the food we eat.

# %% [markdown]
# # Q4. Which category contributes to the maximum % of Cholesterol in a diet (% daily value)?

# %%
df['Category'].nunique()
# Out:
# 9

# %%
sort=pd.DataFrame({'Sorted Category': sorted(df['Category'].unique())})
sort
# Out:
#       Sorted Category
# 0         Beef & Pork
# 1           Beverages
# 2           Breakfast
# 3      Chicken & Fish
# 4        Coffee & Tea
# 5            Desserts
# 6              Salads
# 7  Smoothies & Shakes
# 8      Snacks & Sides

# %%
check = pd.pivot_table(df, 'Cholesterol (% Daily Value)', index=['Category'])


Result = check.sort_values(('Cholesterol (% Daily Value)'), ascending=False)

Result
# Out:
#                     Cholesterol (% Daily Value)
# Category
# Breakfast                             50.952381
# Beef & Pork                           28.933333
# Chicken & Fish                        25.222222
# Salads                                17.333333
# Smoothies & Shakes                    14.714286
# Coffee & Tea                           9.378947
# Snacks & Sides                         6.230769
# Desserts                               4.857143
# Beverages                              0.185185

# %% [markdown]
# ### Above data shows a relation of the 9 Categories to the % Cholesterol.
# ### The data is sorted from 'High' to 'Low' as we move down in the categories

# %% [markdown]
# # Q5. Which item contributes maximum to the Sodium intake?

# %%
check = pd.pivot_table(df, 'Sodium', index=['Item'])


Result = check.sort_values(('Sodium'), ascending=False)

Result.head(10)
# Out:
#                                                     Sodium
# Item
# Chicken McNuggets (40 piece)                          3600
# Big Breakfast with Hotcakes and Egg Whites (Lar...    2290
# Big Breakfast with Hotcakes (Large Biscuit)           2260
# Big Breakfast with Hotcakes and Egg Whites (Reg...    2170
# Big Breakfast with Hotcakes (Regular Biscuit)         2150
# Chicken McNuggets (20 piece)                          1800
# Bacon Clubhouse Crispy Chicken Sandwich               1720
# Big Breakfast with Egg Whites (Large Biscuit)         1700
# Big Breakfast (Large Biscuit)                         1680
# Big Breakfast with Egg Whites (Regular Biscuit)       1590

# %% [markdown]
# # Inference :-
#
#
# ### The item with the Highest Sodium content is  Chicken McNuggets (40 piece)

# %% [markdown]
# # Q6. Which 4 food items contains the most amount of Saturated Fat ?

# %%
check = pd.pivot_table(df, 'Saturated Fat', index=['Item'])


Result = check.sort_values(('Saturated Fat'), ascending=False)

Result.head(10)
# Out:
#                                                Saturated Fat
# Item
# McFlurry with M&M’s Candies (Medium)                    20.0
# Big Breakfast with Hotcakes (Large Biscuit)             20.0
# Chicken McNuggets (40 piece)                            20.0
# Frappé Chocolate Chip (Large)                           20.0
# Double Quarter Pounder with Cheese                      19.0
# Big Breakfast with Hotcakes (Regular Biscuit)           19.0
# Big Breakfast (Large Biscuit)                           18.0
# Frappé Mocha (Large)                                    17.0
# Frappé Chocolate Chip (Medium)                          17.0
# Big Breakfast (Regular Biscuit)                         17.0

# %% [markdown]
# ## Inference :-
#
#
# ### The 4 items with the Highest Saturated Fat content are :-
#
# * McFlurry with M&M’s Candies (Medium)
# * Big Breakfast with Hotcakes (Large Biscuit)
# * Chicken McNuggets (40 piece)
# * Frappé Chocolate Chip (Large)
#
#
#
# #### The End!!!
#
# ## Submitted By:-  Tushar Babbar
